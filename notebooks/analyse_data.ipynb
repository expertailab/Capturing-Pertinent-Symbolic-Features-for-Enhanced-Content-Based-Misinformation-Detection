# %%
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import MinMaxScaler
from collections import OrderedDict
from operator import itemgetter

import pandas as pd
import numpy as np
import copy
import json
import os

# %%
DATA_PATH = "../data/annotated"
TAXONOMIES_PATH = "../data/taxonomies"
datasets = os.listdir(DATA_PATH)
taxonomies = os.listdir(TAXONOMIES_PATH)
taxonomies_names = [tax.split(".")[0] for tax in taxonomies]

# %%
taxonomy_schemas = {}
for filename in os.scandir(TAXONOMIES_PATH):
    with open(filename, "r") as fi:
        taxonomy_schema = {line.strip("\n"):float(0) for line in fi.readlines()}
        taxonomy_schemas[filename.name.split(".")[0]] = taxonomy_schema

# %%
pos_labels = ["contains-bias", "clickbait", "false", "fake", "has_propaganda", "yes", "contains_false", True]

# %%
for dataset in datasets:
    dataset_name = dataset.split(".")[0]
    df = pd.read_csv(f"{DATA_PATH}{os.sep}{dataset}")
    print(dataset_name, df.shape, df["labels"].value_counts().to_dict())
# Out:
# buzzfeed (170, 8) {'real': 90, 'fake': 80}
# twittercovidq2 (260, 8) {'no_false': 223, 'contains_false': 37}
# twittercovidq1 (504, 8) {'yes': 305, 'no': 199}
# clickbait (19038, 8) {'no-clickbait': 14720, 'clickbait': 4318}
# webis (1604, 8) {'true': 1249, 'fake': 355}
# politifact (202, 8) {'real': 111, 'fake': 91}
# propaganda (1594, 8) {'has_propaganda': 816, 'no_propaganda': 778}
# pheme (1685, 8) {True: 1058, False: 627}
# basil (7959, 8) {'no-bias': 6335, 'contains-bias': 1624}

# %%
dataset2tax = {}
for dataset in datasets:
    dataset_name = dataset.split(".")[0]
    df = pd.read_csv(f"{DATA_PATH}{os.sep}{dataset}")
    # scaler = MinMaxScaler()
    # scaler.fit(df)
    # df = scaler.transform(df)
    
    # df = df[df['labels'].isin(pos_labels)]
    df = df[taxonomies_names]
    schemas_deepcopy = copy.deepcopy(taxonomy_schemas)
    for taxonomy_name in taxonomies_names:
        col = df[taxonomy_name].apply(lambda x: json.loads(x))
        col_array = np.vstack(col.values)
        col_mean = np.mean(col_array, axis=0)
        for mean_val, (tax_class, _) in zip(col_mean, schemas_deepcopy[taxonomy_name].items()):
            schemas_deepcopy[taxonomy_name][tax_class] = mean_val
        schemas_deepcopy[taxonomy_name] = OrderedDict(sorted(schemas_deepcopy[taxonomy_name].items(), key=itemgetter(1), reverse=True))
        dataset2tax[dataset_name] = schemas_deepcopy

# %%
for dataset_name, dataset_taxs in dataset2tax.items():
    for taxonomy_name, taxonomy_class in dataset_taxs.items():
        print(f"dataset_name: {dataset_name}, taxonomy_name: {taxonomy_name}")
        class_values_sum = sum([class_val[1] for class_val in taxonomy_class.items()])
        top3 = list(taxonomy_class.items())[:3]
        top_list = []
        for class_name, class_value in top3:
            class_value_freq = class_value*100/class_values_sum
            if class_value_freq != 0:
                top_list.append(f"{class_name} ({round(class_value_freq, 2)}\%)")
            else:
                top_list.append("-")
        
        print_slash = " \\\ "
        print(f"{print_slash.join(top_list)} ")

        print("\n")
# Out:
# dataset_name: buzzfeed, taxonomy_name: radnarr_prj
# Legitimacy of ideology (100.0\%) \\ - \\ -
#
#
# dataset_name: buzzfeed, taxonomy_name: hate_speech
# Personal Insult (50.0\%) \\ Racism (24.1\%) \\ Threat and Violence (24.1\%)
#
#
# dataset_name: buzzfeed, taxonomy_name: sentiment
# positivity (-5.89\%) \\ overall (50.0\%) \\ negativity (55.89\%)
#
#
# dataset_name: buzzfeed, taxonomy_name: behavioral_traits_en
# Extremism (20.5\%) \\ Unlawfulness (10.93\%) \\ Discrimination (9.68\%)
#
#
# dataset_name: buzzfeed, taxonomy_name: emotional_traits_en
# Hatred (20.21\%) \\ Anger (10.45\%) \\ Disgust (10.45\%)
#
#
# dataset_name: buzzfeed, taxonomy_name: writeprint
# Gulpease (32.55\%) \\ charactersPerSentence (27.48\%) \\ atomsPerSentence (5.41\%)
#
#
# dataset_name: twittercovidq2, taxonomy_name: radnarr_prj
# Legitimacy of ideology (70.59\%) \\ Homophily (29.41\%) \\ -
#
#
# dataset_name: twittercovidq2, taxonomy_name: hate_speech
# Threat and Violence (29.59\%) \\ Personal Insult (26.53\%) \\ Body Shaming (18.37\%)
#
#
# dataset_name: twittercovidq2, taxonomy_name: sentiment
# positivity (-18.38\%) \\ overall (49.93\%) \\ negativity (68.45\%)
#
#
# dataset_name: twittercovidq2, taxonomy_name: behavioral_traits_en
# Isolation (13.91\%) \\ Initiative (10.82\%) \\ Rejection (6.8\%)
#
#
# dataset_name: twittercovidq2, taxonomy_name: emotional_traits_en
# Guilt (32.84\%) \\ Fear (9.66\%) \\ Hatred (9.14\%)
#
#
# dataset_name: twittercovidq2, taxonomy_name: writeprint
# charactersPerSentence (31.26\%) \\ Gulpease (18.19\%) \\ tokens (12.63\%)
#
#
# dataset_name: twittercovidq1, taxonomy_name: radnarr_prj
# Legitimacy of ideology (75.0\%) \\ Homophily (15.62\%) \\ Promote group ideology (9.38\%)
#
#
# dataset_name: twittercovidq1, taxonomy_name: hate_speech
# Threat and Violence (29.51\%) \\ Personal Insult (27.66\%) \\ Racism (16.38\%)
#
#
# dataset_name: twittercovidq1, taxonomy_name: sentiment
# positivity (-18.4\%) \\ overall (49.95\%) \\ negativity (68.45\%)
#
#
# dataset_name: twittercovidq1, taxonomy_name: behavioral_traits_en
# Isolation (11.46\%) \\ Initiative (7.52\%) \\ Unawareness (5.96\%)
#
#
# dataset_name: twittercovidq1, taxonomy_name: emotional_traits_en
# Guilt (20.06\%) \\ Anger (17.38\%) \\ Hatred (9.74\%)
#
#
# dataset_name: twittercovidq1, taxonomy_name: writeprint
# charactersPerSentence (30.84\%) \\ Gulpease (19.66\%) \\ tokens (11.54\%)
#
#
# dataset_name: clickbait, taxonomy_name: radnarr_prj
# Legitimacy of ideology (82.64\%) \\ Homophily (9.99\%) \\ Group's achievements (5.3\%)
#
#
# dataset_name: clickbait, taxonomy_name: hate_speech
# Threat and Violence (39.26\%) \\ Racism (26.16\%) \\ Personal Insult (10.07\%)
#
#
# dataset_name: clickbait, taxonomy_name: sentiment
# positivity (-54.74\%) \\ overall (50.0\%) \\ negativity (104.74\%)
#
#
# dataset_name: clickbait, taxonomy_name: behavioral_traits_en
# Violence (14.71\%) \\ Unlawfulness (8.92\%) \\ Initiative (8.68\%)
#
#
# dataset_name: clickbait, taxonomy_name: emotional_traits_en
# Love (10.35\%) \\ Fear (8.14\%) \\ Anger (7.78\%)
#
#
# dataset_name: clickbait, taxonomy_name: writeprint
# Gulpease (29.85\%) \\ charactersPerSentence (29.23\%) \\ atomsPerSentence (5.73\%)
#
#
# dataset_name: webis, taxonomy_name: radnarr_prj
# Legitimacy of ideology (96.24\%) \\ Group's achievements (1.19\%) \\ Homophily (0.99\%)
#
#
# dataset_name: webis, taxonomy_name: hate_speech
# Threat and Violence (33.17\%) \\ Racism (21.07\%) \\ Personal Insult (15.57\%)
#
#
# dataset_name: webis, taxonomy_name: sentiment
# positivity (-38.94\%) \\ overall (49.61\%) \\ negativity (89.33\%)
#
#
# dataset_name: webis, taxonomy_name: behavioral_traits_en
# Violence (14.17\%) \\ Extremism (6.76\%) \\ Initiative (6.51\%)
#
#
# dataset_name: webis, taxonomy_name: emotional_traits_en
# Hatred (10.7\%) \\ Fear (8.3\%) \\ Anger (7.2\%)
#
#
# dataset_name: webis, taxonomy_name: writeprint
# tokens (62.22\%) \\ charactersPerSentence (13.26\%) \\ Gulpease (5.73\%)
#
#
# dataset_name: politifact, taxonomy_name: radnarr_prj
# Legitimacy of ideology (90.71\%) \\ Group's achievements (3.42\%) \\ Homophily (2.1\%)
#
#
# dataset_name: politifact, taxonomy_name: hate_speech
# Threat and Violence (37.93\%) \\ Racism (22.06\%) \\ Personal Insult (14.61\%)
#
#
# dataset_name: politifact, taxonomy_name: sentiment
# positivity (-42.24\%) \\ overall (49.56\%) \\ negativity (92.68\%)
#
#
# dataset_name: politifact, taxonomy_name: behavioral_traits_en
# Violence (13.06\%) \\ Initiative (10.14\%) \\ Rejection (5.32\%)
#
#
# dataset_name: politifact, taxonomy_name: emotional_traits_en
# Anger (12.0\%) \\ Hatred (8.67\%) \\ Love (8.6\%)
#
#
# dataset_name: politifact, taxonomy_name: writeprint
# tokens (62.86\%) \\ charactersPerSentence (12.41\%) \\ Gulpease (6.32\%)
#
#
# dataset_name: propaganda, taxonomy_name: radnarr_prj
# Legitimacy of ideology (83.64\%) \\ Group's achievements (8.39\%) \\ Homophily (3.5\%)
#
#
# dataset_name: propaganda, taxonomy_name: hate_speech
# Threat and Violence (28.56\%) \\ Racism (19.01\%) \\ Religious Hatred (14.18\%)
#
#
# dataset_name: propaganda, taxonomy_name: sentiment
# positivity (-18.08\%) \\ overall (49.99\%) \\ negativity (68.08\%)
#
#
# dataset_name: propaganda, taxonomy_name: behavioral_traits_en
# Violence (18.01\%) \\ Initiative (9.85\%) \\ Unlawfulness (7.33\%)
#
#
# dataset_name: propaganda, taxonomy_name: emotional_traits_en
# Hatred (15.88\%) \\ Fear (11.98\%) \\ Well-Being (8.05\%)
#
#
# dataset_name: propaganda, taxonomy_name: writeprint
# charactersPerSentence (34.16\%) \\ Gulpease (20.85\%) \\ tokens (7.61\%)
#
#
# dataset_name: pheme, taxonomy_name: radnarr_prj
# Legitimacy of ideology (75.0\%) \\ Homophily (13.89\%) \\ Group's achievements (11.11\%)
#
#
# dataset_name: pheme, taxonomy_name: hate_speech
# Threat and Violence (47.59\%) \\ Racism (33.95\%) \\ Ableism (11.07\%)
#
#
# dataset_name: pheme, taxonomy_name: sentiment
# positivity (-8.81\%) \\ overall (49.98\%) \\ negativity (58.84\%)
#
#
# dataset_name: pheme, taxonomy_name: behavioral_traits_en
# Violence (54.54\%) \\ Extremism (10.77\%) \\ Unlawfulness (6.1\%)
#
#
# dataset_name: pheme, taxonomy_name: emotional_traits_en
# Fear (27.48\%) \\ Anger (11.97\%) \\ Hatred (10.12\%)
#
#
# dataset_name: pheme, taxonomy_name: writeprint
# charactersPerSentence (33.35\%) \\ Gulpease (20.74\%) \\ Coleman-Liau (6.79\%)
#
#
# dataset_name: basil, taxonomy_name: radnarr_prj
# Legitimacy of ideology (97.05\%) \\ Homophily (1.2\%) \\ Group's achievements (0.85\%)
#
#
# dataset_name: basil, taxonomy_name: hate_speech
# Threat and Violence (45.8\%) \\ Ableism (13.94\%) \\ Religious Hatred (10.08\%)
#
#
# dataset_name: basil, taxonomy_name: sentiment
# positivity (-45.7\%) \\ overall (50.0\%) \\ negativity (95.71\%)
#
#
# dataset_name: basil, taxonomy_name: behavioral_traits_en
# Initiative (10.96\%) \\ Violence (7.86\%) \\ Rejection (7.69\%)
#
#
# dataset_name: basil, taxonomy_name: emotional_traits_en
# Hatred (9.63\%) \\ Love (8.03\%) \\ Worry (8.02\%)
#
#
# dataset_name: basil, taxonomy_name: writeprint
# charactersPerSentence (37.07\%) \\ Gulpease (14.87\%) \\ atomsPerSentence (7.33\%)

# %%
for dataset_name, dataset_taxs in dataset2tax.items():
    for taxonomy_name, taxonomy_class in dataset_taxs.items():
        top_list = []
        if taxonomy_name == "sentiment":
            print(f"dataset_name: {dataset_name}, taxonomy_name: {taxonomy_name}")
            for item in taxonomy_class.items():
                top_list.append((item[0], round(item[1], 1)))
            print(top_list)
            print("\n")

        if taxonomy_name == "writeprint":
            print(f"dataset_name: {dataset_name}, taxonomy_name: {taxonomy_name}")
            for item in taxonomy_class.items():
                if item[0] in ["Coleman-Liau", "Gulpease", "Automated Readability"]:
                    top_list.append((item[0], round(item[1], 1)))
            print(top_list)
            print("\n")
# Out:
# dataset_name: buzzfeed, taxonomy_name: sentiment
# [('positivity', 1.6), ('overall', -13.9), ('negativity', -15.5)]
#
#
# dataset_name: buzzfeed, taxonomy_name: writeprint
# [('Gulpease', 72.4), ('Coleman-Liau', 9.5), ('Automated Readability', 6.7)]
#
#
# dataset_name: twittercovidq2, taxonomy_name: sentiment
# [('positivity', 2.3), ('overall', -6.4), ('negativity', -8.7)]
#
#
# dataset_name: twittercovidq2, taxonomy_name: writeprint
# [('Gulpease', 61.3), ('Coleman-Liau', 11.5), ('Automated Readability', 10.9)]
#
#
# dataset_name: twittercovidq1, taxonomy_name: sentiment
# [('positivity', 2.4), ('overall', -6.4), ('negativity', -8.8)]
#
#
# dataset_name: twittercovidq1, taxonomy_name: writeprint
# [('Gulpease', 63.7), ('Coleman-Liau', 11.5), ('Automated Readability', 10.7)]
#
#
# dataset_name: clickbait, taxonomy_name: sentiment
# [('positivity', 4.1), ('overall', -3.8), ('negativity', -7.9)]
#
#
# dataset_name: clickbait, taxonomy_name: writeprint
# [('Gulpease', 69.5), ('Coleman-Liau', 9.9), ('Automated Readability', 7.4)]
#
#
# dataset_name: webis, taxonomy_name: sentiment
# [('positivity', 2.5), ('overall', -3.1), ('negativity', -5.6)]
#
#
# dataset_name: webis, taxonomy_name: writeprint
# [('Gulpease', 56.9), ('Automated Readability', 11.9), ('Coleman-Liau', 10.0)]
#
#
# dataset_name: politifact, taxonomy_name: sentiment
# [('positivity', 2.7), ('overall', -3.2), ('negativity', -5.9)]
#
#
# dataset_name: politifact, taxonomy_name: writeprint
# [('Gulpease', 58.9), ('Automated Readability', 10.4), ('Coleman-Liau', 9.5)]
#
#
# dataset_name: propaganda, taxonomy_name: sentiment
# [('positivity', 2.0), ('overall', -5.5), ('negativity', -7.5)]
#
#
# dataset_name: propaganda, taxonomy_name: writeprint
# [('Gulpease', 74.0), ('Automated Readability', 11.0), ('Coleman-Liau', 8.4)]
#
#
# dataset_name: pheme, taxonomy_name: sentiment
# [('positivity', 1.5), ('overall', -8.7), ('negativity', -10.2)]
#
#
# dataset_name: pheme, taxonomy_name: writeprint
# [('Gulpease', 56.0), ('Coleman-Liau', 18.3), ('Automated Readability', 14.6)]
#
#
# dataset_name: basil, taxonomy_name: sentiment
# [('positivity', 2.1), ('overall', -2.3), ('negativity', -4.5)]
#
#
# dataset_name: basil, taxonomy_name: writeprint
# [('Gulpease', 58.2), ('Automated Readability', 13.2), ('Coleman-Liau', 10.4)]

# %%
dataset2pval = {}
for dataset in datasets:
    dataset_name = dataset.split(".")[0]
    df = pd.read_csv(f"{DATA_PATH}{os.sep}{dataset}")
    schemas_deepcopy = copy.deepcopy(taxonomy_schemas)

    id2label = {}
    labels = set(df["labels"].to_list())
    for label in labels:
        if str(label).lower() in pos_labels:
            id2label.update({1: label})
        else:
            id2label.update({0: label})
    label2id  = {id2label[k] : k for k in id2label}

    selected_features = {}
    for col in df.iloc[:,2:].columns:
        col = df[col].apply(lambda x: json.loads(x))
        col_array = np.vstack(col.values)
        _, pvals = f_regression(col_array, df.iloc[:,1].apply(lambda x: label2id[x]).values)
        selected_pval = pvals < 0.05
        selected_features[col.name] = OrderedDict(sorted({class_name: pval_v for pval_v, pval, class_name in zip([round(pval, 2) for pval in pvals], selected_pval, schemas_deepcopy[col.name]) if pval}.items(), key=itemgetter(1), reverse=False))
        dataset2pval[dataset_name] = selected_features

# %%
for dataset_name, dataset_taxs in dataset2pval.items():
    for taxonomy_name, taxonomy_class in dataset_taxs.items():
        print(f"dataset_name: {dataset_name}, taxonomy_name: {taxonomy_name}")
        top3 = list(taxonomy_class.items())[:3]
        top_list = []
        for class_name, class_value in top3:
            top_list.append(f"{class_name} ({class_value})")
        if not top_list:
            print(" - \\\ - \\\ - ")
        else:
            print_slash = " \\\ "
            print(f"{print_slash.join(top_list)} ")

        print("\n")
# Out:
# dataset_name: buzzfeed, taxonomy_name: radnarr_prj
#  - \\ - \\ -
#
#
# dataset_name: buzzfeed, taxonomy_name: hate_speech
#  - \\ - \\ -
#
#
# dataset_name: buzzfeed, taxonomy_name: sentiment
#  - \\ - \\ -
#
#
# dataset_name: buzzfeed, taxonomy_name: behavioral_traits_en
#  - \\ - \\ -
#
#
# dataset_name: buzzfeed, taxonomy_name: emotional_traits_en
#  - \\ - \\ -
#
#
# dataset_name: buzzfeed, taxonomy_name: writeprint
# colonsPerSentence (0.0) \\ exclamationMarksPerSentence (0.0) \\ sentences (0.0)
#
#
# dataset_name: twittercovidq2, taxonomy_name: radnarr_prj
#  - \\ - \\ -
#
#
# dataset_name: twittercovidq2, taxonomy_name: hate_speech
#  - \\ - \\ -
#
#
# dataset_name: twittercovidq2, taxonomy_name: sentiment
#  - \\ - \\ -
#
#
# dataset_name: twittercovidq2, taxonomy_name: behavioral_traits_en
# Sexuality (0.01) \\ Unawareness (0.02) \\ Discrimination (0.04)
#
#
# dataset_name: twittercovidq2, taxonomy_name: emotional_traits_en
# Anger (0.01) \\ Anxiety (0.01) \\ Worry (0.01)
#
#
# dataset_name: twittercovidq2, taxonomy_name: writeprint
# tokens (0.0) \\ emoticonsPerSentence (0.01) \\ Automated Readability (0.03)
#
#
# dataset_name: twittercovidq1, taxonomy_name: radnarr_prj
#  - \\ - \\ -
#
#
# dataset_name: twittercovidq1, taxonomy_name: hate_speech
#  - \\ - \\ -
#
#
# dataset_name: twittercovidq1, taxonomy_name: sentiment
#  - \\ - \\ -
#
#
# dataset_name: twittercovidq1, taxonomy_name: behavioral_traits_en
# Initiative (0.02) \\ Apprehension (0.04) \\ Emotionality (0.05)
#
#
# dataset_name: twittercovidq1, taxonomy_name: emotional_traits_en
#  - \\ - \\ -
#
#
# dataset_name: twittercovidq1, taxonomy_name: writeprint
# Gulpease (0.0) \\ capitalFirstLetterSentences (0.0) \\ charactersPerSentence (0.0)
#
#
# dataset_name: clickbait, taxonomy_name: radnarr_prj
# Legitimacy of ideology (0.0) \\ Discredit enemy (0.05)
#
#
# dataset_name: clickbait, taxonomy_name: hate_speech
# Racism (0.0)
#
#
# dataset_name: clickbait, taxonomy_name: sentiment
# negativity (0.0) \\ overall (0.0) \\ positivity (0.0)
#
#
# dataset_name: clickbait, taxonomy_name: behavioral_traits_en
# Seriousness (0.0) \\ Humour (0.0) \\ Pleasantness (0.0)
#
#
# dataset_name: clickbait, taxonomy_name: emotional_traits_en
# Surprise (0.0) \\ Happiness (0.0) \\ Amusement (0.0)
#
#
# dataset_name: clickbait, taxonomy_name: writeprint
# Coleman-Liau (0.0) \\ Gulpease (0.0) \\ Automated Readability (0.0)
#
#
# dataset_name: webis, taxonomy_name: radnarr_prj
# Legitimacy of ideology (0.0) \\ Discredit enemy (0.01) \\ Attack as self-defense (0.01)
#
#
# dataset_name: webis, taxonomy_name: hate_speech
# Religious Hatred (0.0) \\ Classism (0.01)
#
#
# dataset_name: webis, taxonomy_name: behavioral_traits_en
# Initiative (0.0) \\ Progressiveness (0.0) \\ Competence (0.0)
#
#
# dataset_name: webis, taxonomy_name: emotional_traits_en
# Worry (0.01) \\ Satisfaction (0.01) \\ Hatred (0.03)
#
#
# dataset_name: webis, taxonomy_name: writeprint
# Coleman-Liau (0.0) \\ Gulpease (0.0) \\ Automated Readability (0.0)
#
#
# dataset_name: webis, taxonomy_name: sentiment
# negativity (0.0) \\ overall (0.0) \\ positivity (0.0)
#
#
# dataset_name: politifact, taxonomy_name: radnarr_prj
# Legitimacy of ideology (0.0)
#
#
# dataset_name: politifact, taxonomy_name: hate_speech
# Racism (0.01) \\ Sexism (0.03)
#
#
# dataset_name: politifact, taxonomy_name: sentiment
# negativity (0.05)
#
#
# dataset_name: politifact, taxonomy_name: behavioral_traits_en
# Addiction (0.01) \\ Impoliteness (0.03) \\ Organization (0.03)
#
#
# dataset_name: politifact, taxonomy_name: emotional_traits_en
# Surprise (0.0) \\ Hatred (0.04)
#
#
# dataset_name: politifact, taxonomy_name: writeprint
# auxiliariesPerSentence (0.0) \\ commasPerSentence (0.0) \\ doubleQuotationMarksPerSentence (0.0)
#
#
# dataset_name: propaganda, taxonomy_name: radnarr_prj
# Legitimacy of ideology (0.0) \\ Discredit enemy (0.02)
#
#
# dataset_name: propaganda, taxonomy_name: hate_speech
# Religious Hatred (0.0)
#
#
# dataset_name: propaganda, taxonomy_name: sentiment
# negativity (0.0) \\ overall (0.0)
#
#
# dataset_name: propaganda, taxonomy_name: behavioral_traits_en
# Violence (0.0) \\ Extremism (0.0) \\ Disagreement (0.01)
#
#
# dataset_name: propaganda, taxonomy_name: emotional_traits_en
# Hatred (0.01) \\ Disgust (0.02) \\ Offence (0.05)
#
#
# dataset_name: propaganda, taxonomy_name: writeprint
# Coleman-Liau (0.0) \\ Gulpease (0.0) \\ Automated Readability (0.0)
#
#
# dataset_name: pheme, taxonomy_name: radnarr_prj
# Homophily (0.01)
#
#
# dataset_name: pheme, taxonomy_name: hate_speech
# Racism (0.01)
#
#
# dataset_name: pheme, taxonomy_name: behavioral_traits_en
# Bias (0.0) \\ Violence (0.0) \\ Humour (0.02)
#
#
# dataset_name: pheme, taxonomy_name: emotional_traits_en
# Surprise (0.0) \\ Disappointment (0.02) \\ Hatred (0.04)
#
#
# dataset_name: pheme, taxonomy_name: writeprint
# Coleman-Liau (0.0) \\ Gulpease (0.0) \\ Automated Readability (0.0)
#
#
# dataset_name: pheme, taxonomy_name: sentiment
# negativity (0.0) \\ overall (0.0) \\ positivity (0.02)
#
#
# dataset_name: basil, taxonomy_name: radnarr_prj
# Group's achievements (0.05)
#
#
# dataset_name: basil, taxonomy_name: hate_speech
#  - \\ - \\ -
#
#
# dataset_name: basil, taxonomy_name: behavioral_traits_en
# Impoliteness (0.0) \\ Calmness (0.0) \\ Rejection (0.0)
#
#
# dataset_name: basil, taxonomy_name: emotional_traits_en
# Worry (0.0) \\ Shame (0.0) \\ Offence (0.0)
#
#
# dataset_name: basil, taxonomy_name: writeprint
# Gulpease (0.0) \\ Automated Readability (0.0) \\ adjectivesPerSentence (0.0)
#
#
# dataset_name: basil, taxonomy_name: sentiment
# negativity (0.0) \\ overall (0.0) \\ positivity (0.0)
